# %%
from CircularGraph import CircularGraph
from pathlib import Path
g = CircularGraph(
    mat_path= Path("Main__Data/rs_feat_mats_mayas_data_pearson.csv"),
    mat_type="edge_list",
    labels=Path("Atlases/labels_scf_100.csv"),
    secondary_labels=Path("Atlases/Schaefer_100parcels_7Network_Canonical.csv"),
    color_palette=Path("Color Palettes/yeo_7_network_colors.csv")
)

print(g.mat.shape)
print(g.labels)
print(g.secondary_labels)
print(g.color_palette)
# Out:
# (100, 100)
# ...

# %%
from CircularGraph import CircularGraph
g2 = CircularGraph(
    mat_path="Main__Data\\rs_feat_mats_mayas_data_pearson.csv",
    mat_type="edge_list",
    labels="Atlases\labels_scf_100.csv",
    secondary_labels="Atlases\Schaefer_100parcels_7Network_Canonical.csv",
    color_palette="Color Palettes\\wrong_colors.csv"
)

print(g2.mat.shape)
print(g2.labels)
print(g2.secondary_labels)
print(g2.color_palette)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[2], line 2
#       1 from CircularGraph import CircularGraph
# ----> 2 g2 = CircularGraph(
#       3     mat_path="Main__Data\\rs_feat_mats_mayas_data_pearson.csv",
#       4     mat_type="edge_list",
#       5     labels="Atlases\labels_scf_100.csv",
#       6     secondary_labels="Atlases\Schaefer_100parcels_7Network_Canonical.csv",
#       7     color_palette="Color Palettes\\wrong_colors.csv"
#       8 )
#      10 print(g2.mat.shape)
#      11 print(g2.labels)
#
# File c:\Users\User\Downloads\circular-graphs\CircularGraph.py:25, in CircularGraph.__init__(self, mat_path, mat_type, labels, secondary_labels, color_palette)
#      22 self.secondary_labels = load_secondary_labels(secondary_labels)
#      23 self.color_palette = load_color_palette(color_palette)
# ---> 25 self._validate()
#
# ...

# %%
from CircularGraph import CircularGraph
g3 = CircularGraph(
    mat_path="Main__Data\Math_KRR_permutation_feature_importance.mat",
    mat_type="matrix",
    labels="Atlases\labels_scf_100.csv",
    secondary_labels="Atlases\Schaefer_100parcels_7Network_Canonical.csv",
    color_palette="Color Palettes\\yeo_7_network_colors.csv"
)

print(g3.mat.shape)
print(g3.labels)
print(g3.secondary_labels)
print(g3.color_palette)
# Out:
# (100, 100)
# ...

# %%
(g3.mat == g3.mat.T).all()
# Out:
# np.True_

# %%
g.plot(label=False, sec_label="Bracket", edge_color_method="PositiveNegative", sec_label_size=10)
